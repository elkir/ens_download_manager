# %%
import pandas as pd
import numpy as np

from pathlib import Path
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
Path().cwd()
filename = Path("../data/mars_01d_days15-46.list")
filename,filename.exists()
# Out:
# PosixPath('/local/scratch/home/pd423/ph6/01_ens-extended_download')
# (PosixPath('data/mars_01d_days15-46.list'), True)

# %%
df = pd.read_table(filename, header=12,skipfooter=6,delim_whitespace=True,
                   dtype={'file': 'int',
                        'length': 'int',
                        'missing': 'str',
                        'number': 'int',
                        'offset': 'int',
                        'param': 'str',
                        'step': 'int'}
                   )
df
# Out:
# /tmp/ipykernel_47693/2928224734.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_table(filename, header=12,skipfooter=6,delim_whitespace=True,
#        file   length missing  number         offset    param  step
# 0         0  3325602       .       1   627137823680   22.228   360
# 1         0  3325602       .       1   627266498316  129.128   360
# 2         0  3325602       .       1   627276475122  134.128   360
# 3         0  3325602       .       1   627328020592  165.128   360
# 4         0  3325602       .       1   627331346194  166.128   360
# ...     ...      ...     ...     ...            ...      ...   ...
# 79845     0   843682       .      50  1084986187111  178.128  1104
# 79846     0   843682       .      50  1084993780249  205.128  1104
# 79847     0   843682       .      50  1084999686023  236.128  1104
# 79848     0   843682       .      50  1085000529705  246.228  1104
# 79849     0   843682       .      50  1085001373387  247.228  1104
#
# [79850 rows x 7 columns]

# %%
df.describe()
# Out:
#           file        length       number        offset          step
# count  79850.0  7.985000e+04  79850.00000  7.985000e+04  79850.000000
# mean       0.0  8.685478e+05     25.50000  8.638965e+11    731.767063
# std        0.0  2.471790e+05     14.43096  1.278889e+11    216.942410
# min        0.0  8.436820e+05      1.00000  6.271378e+11    360.000000
# 25%        0.0  8.436820e+05     13.00000  7.534466e+11    546.000000
# 50%        0.0  8.436820e+05     25.50000  8.639577e+11    732.000000
# 75%        0.0  8.436820e+05     38.00000  9.744960e+11    918.000000
# max        0.0  3.325602e+06     50.00000  1.085001e+12   1104.000000

# %%
df.pivot_table(
    index="number",
    columns="param",
    values="step",
    # margins=True,
    aggfunc='count'
)
# Out:
# param   129.128  134.128  165.128  166.128  167.128  169.128  173.128  \
# number
# 1           125      125      125      125      125      125       32
# 2           125      125      125      125      125      125       32
# 3           125      125      125      125      125      125       32
# 4           125      125      125      125      125      125       32
# 5           125      125      125      125      125      125       32
# 6           125      125      125      125      125      125       32
# 7           125      125      125      125      125      125       32
# 8           125      125      125      125      125      125       32
# 9           125      125      125      125      125      125       32
# 10          125      125      125      125      125      125       32
# 11          125      125      125      125      125      125       32
# 12          125      125      125      125      125      125       32
# 13          125      125      125      125      125      125       32
# 14          125      125      125      125      125      125       32
# 15          125      125      125      125      125      125       32
# 16          125      125      125      125      125      125       32
# 17          125      125      125      125      125      125       32
# 18          125      125      125      125      125      125       32
# 19          125      125      125      125      125      125       32
# 20          125      125      125      125      125      125       32
# 21          125      125      125      125      125      125       32
# 22          125      125      125      125      125      125       32
# 23          125      125      125      125      125      125       32
# 24          125      125      125      125      125      125       32
# 25          125      125      125      125      125      125       32
# 26          125      125      125      125      125      125       32
# 27          125      125      125      125      125      125       32
# 28          125      125      125      125      125      125       32
# 29          125      125      125      125      125      125       32
# 30          125      125      125      125      125      125       32
# 31          125      125      125      125      125      125       32
# 32          125      125      125      125      125      125       32
# 33          125      125      125      125      125      125       32
# 34          125      125      125      125      125      125       32
# 35          125      125      125      125      125      125       32
# 36          125      125      125      125      125      125       32
# 37          125      125      125      125      125      125       32
# 38          125      125      125      125      125      125       32
# 39          125      125      125      125      125      125       32
# 40          125      125      125      125      125      125       32
# 41          125      125      125      125      125      125       32
# 42          125      125      125      125      125      125       32
# 43          125      125      125      125      125      125       32
# 44          125      125      125      125      125      125       32
# 45          125      125      125      125      125      125       32
# 46          125      125      125      125      125      125       32
# 47          125      125      125      125      125      125       32
# 48          125      125      125      125      125      125       32
# 49          125      125      125      125      125      125       32
# 50          125      125      125      125      125      125       32
#
# param   174.128  175.128  176.128  178.128  205.128  22.228  236.128  246.228  \
# number
# 1            32      125      125       32      125       1      125      125
# 2            32      125      125       32      125       1      125      125
# 3            32      125      125       32      125       1      125      125
# 4            32      125      125       32      125       1      125      125
# 5            32      125      125       32      125       1      125      125
# 6            32      125      125       32      125       1      125      125
# 7            32      125      125       32      125       1      125      125
# 8            32      125      125       32      125       1      125      125
# 9            32      125      125       32      125       1      125      125
# 10           32      125      125       32      125       1      125      125
# 11           32      125      125       32      125       1      125      125
# 12           32      125      125       32      125       1      125      125
# 13           32      125      125       32      125       1      125      125
# 14           32      125      125       32      125       1      125      125
# 15           32      125      125       32      125       1      125      125
# 16           32      125      125       32      125       1      125      125
# 17           32      125      125       32      125       1      125      125
# 18           32      125      125       32      125       1      125      125
# 19           32      125      125       32      125       1      125      125
# 20           32      125      125       32      125       1      125      125
# 21           32      125      125       32      125       1      125      125
# 22           32      125      125       32      125       1      125      125
# 23           32      125      125       32      125       1      125      125
# 24           32      125      125       32      125       1      125      125
# 25           32      125      125       32      125       1      125      125
# 26           32      125      125       32      125       1      125      125
# 27           32      125      125       32      125       1      125      125
# 28           32      125      125       32      125       1      125      125
# 29           32      125      125       32      125       1      125      125
# 30           32      125      125       32      125       1      125      125
# 31           32      125      125       32      125       1      125      125
# 32           32      125      125       32      125       1      125      125
# 33           32      125      125       32      125       1      125      125
# 34           32      125      125       32      125       1      125      125
# 35           32      125      125       32      125       1      125      125
# 36           32      125      125       32      125       1      125      125
# 37           32      125      125       32      125       1      125      125
# 38           32      125      125       32      125       1      125      125
# 39           32      125      125       32      125       1      125      125
# 40           32      125      125       32      125       1      125      125
# 41           32      125      125       32      125       1      125      125
# 42           32      125      125       32      125       1      125      125
# 43           32      125      125       32      125       1      125      125
# 44           32      125      125       32      125       1      125      125
# 45           32      125      125       32      125       1      125      125
# 46           32      125      125       32      125       1      125      125
# 47           32      125      125       32      125       1      125      125
# 48           32      125      125       32      125       1      125      125
# 49           32      125      125       32      125       1      125      125
# 50           32      125      125       32      125       1      125      125
#
# param   247.228
# number
# 1           125
# 2           125
# 3           125
# 4           125
# 5           125
# 6           125
# 7           125
# 8           125
# 9           125
# 10          125
# 11          125
# 12          125
# 13          125
# 14          125
# 15          125
# 16          125
# 17          125
# 18          125
# 19          125
# 20          125
# 21          125
# 22          125
# 23          125
# 24          125
# 25          125
# 26          125
# 27          125
# 28          125
# 29          125
# 30          125
# 31          125
# 32          125
# 33          125
# 34          125
# 35          125
# 36          125
# 37          125
# 38          125
# 39          125
# 40          125
# 41          125
# 42          125
# 43          125
# 44          125
# 45          125
# 46          125
# 47          125
# 48          125
# 49          125
# 50          125
